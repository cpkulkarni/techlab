# %%
import pdfkit

# %%
def convert_url_to_pdf(url, pdf_path):
    try:
        pdfkit.from_url(url, pdf_path)
        print(f"PDF generated and saved at {pdf_path}")
    except Exception as e:
        print(f"PDF generation failed: {e}")

# %%
url_to_fetch = 'https://apitemplate.io/blog/how-to-convert-html-to-pdf-using-python/'

# %%
import pdfkit

def convert_url_to_pdf(url, pdf_path):
    try:
        pdfkit.from_url(url, pdf_path)
        print(f"PDF generated and saved at {pdf_path}")
    except Exception as e:
        print(f"PDF generation failed: {e}")

# URL to fetch
url_to_fetch = 'https://apitemplate.io/blog/how-to-convert-html-to-pdf-using-python/'

# PDF path to save
pdf_path = 'test.pdf'

# Generate PDF
convert_url_to_pdf(url_to_fetch, pdf_path)
# Out:
# PDF generation failed: No wkhtmltopdf executable found: "b''"
# If this file exists please check that this process can read it or you can pass path to it manually in method call, check README. Otherwise please install wkhtmltopdf - https://github.com/JazzCore/python-pdfkit/wiki/Installing-wkhtmltopdf

# %%
pdf_path = 'test.pdf'

# %%
convert_url_to_pdf(url_to_fetch, pdf_path)
# Out:
# PDF generation failed: No wkhtmltopdf executable found: "b''"
# If this file exists please check that this process can read it or you can pass path to it manually in method call, check README. Otherwise please install wkhtmltopdf - https://github.com/JazzCore/python-pdfkit/wiki/Installing-wkhtmltopdf

# %%
convert_url_to_pdf(url_to_fetch, pdf_path)
# Out:
# PDF generation failed: No wkhtmltopdf executable found: "b''"
# If this file exists please check that this process can read it or you can pass path to it manually in method call, check README. Otherwise please install wkhtmltopdf - https://github.com/JazzCore/python-pdfkit/wiki/Installing-wkhtmltopdf

# %%
convert_url_to_pdf(url_to_fetch, pdf_path)
# Out:
# PDF generation failed: No wkhtmltopdf executable found: "b''"
# If this file exists please check that this process can read it or you can pass path to it manually in method call, check README. Otherwise please install wkhtmltopdf - https://github.com/JazzCore/python-pdfkit/wiki/Installing-wkhtmltopdf

# %%
convert_url_to_pdf(url_to_fetch, pdf_path)
# Out:
# PDF generation failed: No wkhtmltopdf executable found: "b''"
# If this file exists please check that this process can read it or you can pass path to it manually in method call, check README. Otherwise please install wkhtmltopdf - https://github.com/JazzCore/python-pdfkit/wiki/Installing-wkhtmltopdf

# %%
convert_url_to_pdf(url_to_fetch, pdf_path)
# Out:
# PDF generation failed: No wkhtmltopdf executable found: "b''"
# If this file exists please check that this process can read it or you can pass path to it manually in method call, check README. Otherwise please install wkhtmltopdf - https://github.com/JazzCore/python-pdfkit/wiki/Installing-wkhtmltopdf

# %% [markdown]
# Restarted Python 3.12.2

# %%
import pdfkit

def convert_url_to_pdf(url, pdf_path):
    try:
        pdfkit.from_url(url, pdf_path)
        print(f"PDF generated and saved at {pdf_path}")
    except Exception as e:
        print(f"PDF generation failed: {e}")

# URL to fetch
url_to_fetch = 'https://apitemplate.io/blog/how-to-convert-html-to-pdf-using-python/'

# PDF path to save
pdf_path = 'test.pdf'

# Generate PDF
convert_url_to_pdf(url_to_fetch, pdf_path)
# Out:
# PDF generation failed: No wkhtmltopdf executable found: "b''"
# If this file exists please check that this process can read it or you can pass path to it manually in method call, check README. Otherwise please install wkhtmltopdf - https://github.com/JazzCore/python-pdfkit/wiki/Installing-wkhtmltopdf

# %%
import pdfkit

def convert_url_to_pdf(url, pdf_path):
    try:
        config = pdfkit.configuration(wkhtmltopdf='C:\Program Files\wkhtmltopdf\bin')
        pdfkit.from_url(url, pdf_path, configuration=config)
        print(f"PDF generated and saved at {pdf_path}")
    except Exception as e:
        print(f"PDF generation failed: {e}")

# URL to fetch
url_to_fetch = 'https://apitemplate.io/blog/how-to-convert-html-to-pdf-using-python/'

# PDF path to save
pdf_path = 'test.pdf'

# Generate PDF
convert_url_to_pdf(url_to_fetch, pdf_path)
# Out:
# PDF generation failed: No wkhtmltopdf executable found: "C:\Program Files\wkhtmltopdin"
# If this file exists please check that this process can read it or you can pass path to it manually in method call, check README. Otherwise please install wkhtmltopdf - https://github.com/JazzCore/python-pdfkit/wiki/Installing-wkhtmltopdf
# <>:5: SyntaxWarning: invalid escape sequence '\P'
# <>:5: SyntaxWarning: invalid escape sequence '\P'
# <ipython-input-2-f6cbc971f775>:5: SyntaxWarning: invalid escape sequence '\P'
#   config = pdfkit.configuration(wkhtmltopdf='C:\Program Files\wkhtmltopdf\bin')

# %%
import pdfkit

def convert_url_to_pdf(url, pdf_path):
    try:
        config = pdfkit.configuration(wkhtmltopdf='C:\"Program Files"\wkhtmltopdf\bin')
        pdfkit.from_url(url, pdf_path, configuration=config)
        print(f"PDF generated and saved at {pdf_path}")
    except Exception as e:
        print(f"PDF generation failed: {e}")

# URL to fetch
url_to_fetch = 'https://apitemplate.io/blog/how-to-convert-html-to-pdf-using-python/'

# PDF path to save
pdf_path = 'test.pdf'

# Generate PDF
convert_url_to_pdf(url_to_fetch, pdf_path)
# Out:
# PDF generation failed: No wkhtmltopdf executable found: "C:"Program Files"\wkhtmltopdin"
# If this file exists please check that this process can read it or you can pass path to it manually in method call, check README. Otherwise please install wkhtmltopdf - https://github.com/JazzCore/python-pdfkit/wiki/Installing-wkhtmltopdf
# <>:5: SyntaxWarning: invalid escape sequence '\w'
# <>:5: SyntaxWarning: invalid escape sequence '\w'
# <ipython-input-3-c1171cd63663>:5: SyntaxWarning: invalid escape sequence '\w'
#   config = pdfkit.configuration(wkhtmltopdf='C:\"Program Files"\wkhtmltopdf\bin')

# %%
import pdfkit

def convert_url_to_pdf(url, pdf_path):
    try:
        config = pdfkit.configuration(wkhtmltopdf='C:/"Program Files"/wkhtmltopdf/bin')
        pdfkit.from_url(url, pdf_path, configuration=config)
        print(f"PDF generated and saved at {pdf_path}")
    except Exception as e:
        print(f"PDF generation failed: {e}")

# URL to fetch
url_to_fetch = 'https://apitemplate.io/blog/how-to-convert-html-to-pdf-using-python/'

# PDF path to save
pdf_path = 'test.pdf'

# Generate PDF
convert_url_to_pdf(url_to_fetch, pdf_path)
# Out:
# PDF generation failed: No wkhtmltopdf executable found: "C:/"Program Files"/wkhtmltopdf/bin"
# If this file exists please check that this process can read it or you can pass path to it manually in method call, check README. Otherwise please install wkhtmltopdf - https://github.com/JazzCore/python-pdfkit/wiki/Installing-wkhtmltopdf

# %%
import pdfkit

def convert_url_to_pdf(url, pdf_path):
    try:
        config = pdfkit.configuration(wkhtmltopdf='C:/Program Files/wkhtmltopdf/bin')
        pdfkit.from_url(url, pdf_path, configuration=config)
        print(f"PDF generated and saved at {pdf_path}")
    except Exception as e:
        print(f"PDF generation failed: {e}")

# URL to fetch
url_to_fetch = 'https://apitemplate.io/blog/how-to-convert-html-to-pdf-using-python/'

# PDF path to save
pdf_path = 'test.pdf'

# Generate PDF
convert_url_to_pdf(url_to_fetch, pdf_path)
# Out:
# PDF generation failed: No wkhtmltopdf executable found: "C:/Program Files/wkhtmltopdf/bin"
# If this file exists please check that this process can read it or you can pass path to it manually in method call, check README. Otherwise please install wkhtmltopdf - https://github.com/JazzCore/python-pdfkit/wiki/Installing-wkhtmltopdf

# %%
import pdfkit

def convert_url_to_pdf(url, pdf_path):
    try:
        config = pdfkit.configuration(wkhtmltopdf='C:/Program Files/wkhtmltopdf/')
        pdfkit.from_url(url, pdf_path, configuration=config)
        print(f"PDF generated and saved at {pdf_path}")
    except Exception as e:
        print(f"PDF generation failed: {e}")

# URL to fetch
url_to_fetch = 'https://apitemplate.io/blog/how-to-convert-html-to-pdf-using-python/'

# PDF path to save
pdf_path = 'test.pdf'

# Generate PDF
convert_url_to_pdf(url_to_fetch, pdf_path)
# Out:
# PDF generation failed: No wkhtmltopdf executable found: "C:/Program Files/wkhtmltopdf/"
# If this file exists please check that this process can read it or you can pass path to it manually in method call, check README. Otherwise please install wkhtmltopdf - https://github.com/JazzCore/python-pdfkit/wiki/Installing-wkhtmltopdf

# %%
import pdfkit

def convert_url_to_pdf(url, pdf_path):
    try:
        config = pdfkit.configuration(wkhtmltopdf='C:\\Program Files\\wkhtmltopdf')
        pdfkit.from_url(url, pdf_path, configuration=config)
        print(f"PDF generated and saved at {pdf_path}")
    except Exception as e:
        print(f"PDF generation failed: {e}")

# URL to fetch
url_to_fetch = 'https://apitemplate.io/blog/how-to-convert-html-to-pdf-using-python/'

# PDF path to save
pdf_path = 'test.pdf'

# Generate PDF
convert_url_to_pdf(url_to_fetch, pdf_path)
# Out:
# PDF generation failed: No wkhtmltopdf executable found: "C:\Program Files\wkhtmltopdf"
# If this file exists please check that this process can read it or you can pass path to it manually in method call, check README. Otherwise please install wkhtmltopdf - https://github.com/JazzCore/python-pdfkit/wiki/Installing-wkhtmltopdf

# %%
import pdfkit

def convert_url_to_pdf(url, pdf_path):
    try:
        config = pdfkit.configuration(wkhtmltopdf='C:\\Program Files\\wkhtmltopdf\\bin')
        pdfkit.from_url(url, pdf_path, configuration=config)
        print(f"PDF generated and saved at {pdf_path}")
    except Exception as e:
        print(f"PDF generation failed: {e}")

# URL to fetch
url_to_fetch = 'https://apitemplate.io/blog/how-to-convert-html-to-pdf-using-python/'

# PDF path to save
pdf_path = 'test.pdf'

# Generate PDF
convert_url_to_pdf(url_to_fetch, pdf_path)
# Out:
# PDF generation failed: No wkhtmltopdf executable found: "C:\Program Files\wkhtmltopdf\bin"
# If this file exists please check that this process can read it or you can pass path to it manually in method call, check README. Otherwise please install wkhtmltopdf - https://github.com/JazzCore/python-pdfkit/wiki/Installing-wkhtmltopdf

# %%
from xhtml2pdf import pisa
import requests

def convert_url_to_pdf(url, pdf_path):
    # Fetch the HTML content from the URL
    response = requests.get(url)
    if response.status_code != 200:
        print(f"Failed to fetch URL: {url}")
        return False
    
    html_content = response.text
    
    # Generate PDF
    with open(pdf_path, "wb") as pdf_file:
        pisa_status = pisa.CreatePDF(html_content, dest=pdf_file)
        
    return not pisa_status.err

# URL to fetch
url_to_fetch = "https://apitemplate.io/blog/how-to-convert-html-to-pdf-using-python/"

# PDF path to save
pdf_path = "test.pdf"

# Generate PDF
if convert_url_to_pdf(url_to_fetch, pdf_path):
    print(f"PDF generated and saved at {pdf_path}")
else:
    print("PDF generation failed")
# Out:
# Error while parsing CSS file
# Traceback (most recent call last):
#   File "C:\Python312\Lib\site-packages\xhtml2pdf\context.py", line 513, in parseExternal
#     result = self.parse(cssFile.getData())
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Python312\Lib\site-packages\xhtml2pdf\w3c\cssParser.py", line 458, in parse
#     src, stylesheet = self._parseStylesheet(src)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Python312\Lib\site-packages\xhtml2pdf\w3c\cssParser.py", line 566, in _parseStylesheet
#     src, ruleset = self._parseRuleset(src)
#                    ^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Python312\Lib\site-packages\xhtml2pdf\w3c\cssParser.py", line 918, in _parseRuleset
#     src, selectors = self._parseSelectorGroup(src)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Python312\Lib\site-packages\xhtml2pdf\w3c\cssParser.py", line 928, in _parseSelectorGroup
#     src, selector = self._parseSelector(src)
# ...

# %%
from xhtml2pdf import pisa
import requests

def convert_url_to_pdf(url, pdf_path):
    # Fetch the HTML content from the URL
    response = requests.get(url)
    if response.status_code != 200:
        print(f"Failed to fetch URL: {url}")
        return False
    
    html_content = response.text
    
    # Generate PDF
    with open(pdf_path, "wb") as pdf_file:
        pisa_status = pisa.CreatePDF(html_content, dest=pdf_file)
        
    return not pisa_status.err

# URL to fetch
url_to_fetch = "https://www.geeksforgeeks.org/python-program-for-word-guessing-game/"

# PDF path to save
pdf_path = "test.pdf"

# Generate PDF
if convert_url_to_pdf(url_to_fetch, pdf_path):
    print(f"PDF generated and saved at {pdf_path}")
else:
    print("PDF generation failed")
# Out:
# Error while parsing CSS file
# Traceback (most recent call last):
#   File "C:\Python312\Lib\site-packages\xhtml2pdf\context.py", line 513, in parseExternal
#     result = self.parse(cssFile.getData())
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Python312\Lib\site-packages\xhtml2pdf\w3c\cssParser.py", line 458, in parse
#     src, stylesheet = self._parseStylesheet(src)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Python312\Lib\site-packages\xhtml2pdf\w3c\cssParser.py", line 566, in _parseStylesheet
#     src, ruleset = self._parseRuleset(src)
#                    ^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Python312\Lib\site-packages\xhtml2pdf\w3c\cssParser.py", line 918, in _parseRuleset
#     src, selectors = self._parseSelectorGroup(src)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Python312\Lib\site-packages\xhtml2pdf\w3c\cssParser.py", line 928, in _parseSelectorGroup
#     src, selector = self._parseSelector(src)
# ...

# %%
from xhtml2pdf import pisa
import requests

def convert_url_to_pdf(url, pdf_path):
    # Fetch the HTML content from the URL
    response = requests.get(url)
    if response.status_code != 200:
        print("Failed to fetch URL:",url)
        return False
    
    html_content = response.text
    
    # Generate PDF
    with open(pdf_path, "wb") as pdf_file:
        pisa_status = pisa.CreatePDF(html_content, dest=pdf_file)
        
    return not pisa_status.err

# URL to fetch
url_to_fetch = "https://www.geeksforgeeks.org/python-program-for-word-guessing-game/"

# PDF path to save
pdf_path = "test.pdf"

# Generate PDF
if convert_url_to_pdf(url_to_fetch, pdf_path):
    print(f"PDF generated and saved at {pdf_path}")
else:
    print("PDF generation failed")
# Out:
# Error while parsing CSS file
# Traceback (most recent call last):
#   File "C:\Python312\Lib\site-packages\xhtml2pdf\context.py", line 513, in parseExternal
#     result = self.parse(cssFile.getData())
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Python312\Lib\site-packages\xhtml2pdf\w3c\cssParser.py", line 458, in parse
#     src, stylesheet = self._parseStylesheet(src)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Python312\Lib\site-packages\xhtml2pdf\w3c\cssParser.py", line 566, in _parseStylesheet
#     src, ruleset = self._parseRuleset(src)
#                    ^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Python312\Lib\site-packages\xhtml2pdf\w3c\cssParser.py", line 918, in _parseRuleset
#     src, selectors = self._parseSelectorGroup(src)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Python312\Lib\site-packages\xhtml2pdf\w3c\cssParser.py", line 928, in _parseSelectorGroup
#     src, selector = self._parseSelector(src)
# ...
